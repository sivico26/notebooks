# %% [markdown]
# # Clase 2:

# %% [markdown]
# ### **Temas interesantes**
#
# Test hipergeometrico, para diferenciar mis resultados del azar (se basa en la distribución binomial)

# %% [markdown]
# GWAS: Genome wide association analysis. Asocia genes con fenotipos. Ver [GWAS catalog](https://www.ebi.ac.uk/gwas/diagram)

# %% [markdown]
# #### **Prog. orientada a objetos**
#
# Hay una separación entre Entidades/Relaciones
#
# ##### **Entidades**
#
# - Asociación
#     - Fecha de Adición
# - Estudio
#     - Pubmed ID
#     - Autor
#     - Date
#     - Journal
#     - Link
#     - Tilte
# - Journal
#     - name
# - Trait
#     - name

# %% [markdown]
# Pandas es la librería que os permite hacer **análisis de datos**

# %%
import pandas as pd

# %%
gwas = pd.read_csv('~/Downloads/gwas_catalog.tsv', sep = '\t')

# %%
gwas.head()
# Out:
#   DATE ADDED TO CATALOG  PUBMEDID FIRST AUTHOR        DATE       JOURNAL  \
# 0            2009-09-28  18403759       Ober C  2008-04-09  N Engl J Med
# 1            2008-06-16  18369459        Liu Y  2008-04-04    PLoS Genet
# 2            2008-06-16  18385676      Amos CI  2008-04-03     Nat Genet
# 3            2008-06-16  18385676      Amos CI  2008-04-03     Nat Genet
# 4            2008-06-16  18385676      Amos CI  2008-04-03     Nat Genet
#
#                                    LINK  \
# 0  www.ncbi.nlm.nih.gov/pubmed/18403759
# 1  www.ncbi.nlm.nih.gov/pubmed/18369459
# 2  www.ncbi.nlm.nih.gov/pubmed/18385676
# 3  www.ncbi.nlm.nih.gov/pubmed/18385676
# 4  www.ncbi.nlm.nih.gov/pubmed/18385676
#
#                                                STUDY  DISEASE/TRAIT  \
# 0  Effect of variation in CHI3L1 on serum YKL-40 ...  YKL-40 levels
# 1  A genome-wide association study of psoriasis a...      Psoriasis
# 2  Genome-wide association scan of tag SNPs ident...    Lung cancer
# ...

# %%
## Cuantos estudios hay? 2 formas de hacerlo

len(set(gwas.PUBMEDID.tolist()))
# Out:
# 2849

# %%
gwas.PUBMEDID.drop_duplicates().size
# Out:
# 2849

# %%
## ¿Qué ṕorcentaje de autores tiene más de un estudio?

gwas["FIRST AUTHOR"]
# Out:
# 0                 Ober C
# 1                  Liu Y
# 2                Amos CI
# 3                Amos CI
# 4                Amos CI
# 5                Hung RJ
# 6        Thorgeirsson TE
# 7               Tenesa A
# 8               Tenesa A
# 9               Tenesa A
# 10          Tomlinson IP
# 11          Tomlinson IP
# 12             Zeggini E
# 13             Zeggini E
# 14             Zeggini E
# 15             Zeggini E
# 16             Zeggini E
# 17                Gold B
# 18               Kirov G
# 19              Doring A
# 20              Vitart V
# 21               Hunt KA
# 22               Hunt KA
# 23               Hunt KA
# 24               Hunt KA
# 25               Hunt KA
# 26              Eeles RA
# 27              Eeles RA
# 28              Eeles RA
# 29              Eeles RA
#               ...
# 67200            Hill WD
# 67201            Hill WD
# 67202            Hill WD
# 67203            Hill WD
# 67204            Hill WD
# 67205            Hill WD
# ...
